# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
graffiti_file = "311-service-requests-graffiti-removal.csv"
graffiti_df = pd.read_csv(graffiti_file)
graffiti_df.head()
# Out:
#              Creation Date     Status          Completion Date  \
# 0  2018-12-18T00:00:00.000       Open                      NaN
# 1  2018-12-18T00:00:00.000  Completed  2018-12-19T00:00:00.000
# 2  2018-12-18T00:00:00.000       Open                      NaN
# 3  2018-12-18T00:00:00.000  Completed  2018-12-19T00:00:00.000
# 4  2018-12-18T00:00:00.000       Open                      NaN
#
#   Service Request Number Type of Service Request  \
# 0            18-03388261        Graffiti Removal
# 1            18-03387473        Graffiti Removal
# 2            18-03388465        Graffiti Removal
# 3            18-03388768        Graffiti Removal
# 4            18-03387763        Graffiti Removal
#
#   What Type of Surface is the Graffiti on? Where is the Graffiti located?  \
# 0                        Brick - Unpainted                          Alley
# 1                             Vinyl Siding                         Garage
# ...

# %%
lights_all_file = "311-service-requests-street-lights-all-out.csv"
lights_all_df = pd.read_csv(lights_all_file)
lights_all_df.head()
# Out:
#              Creation Date      Status Completion Date Service Request Number  \
# 0  2018-12-18T00:00:00.000        Open             NaN            18-03388534
# 1  2018-12-18T00:00:00.000        Open             NaN            18-03387781
# 2  2018-12-18T00:00:00.000  Open - Dup             NaN            18-03387616
# 3  2018-12-18T00:00:00.000        Open             NaN            18-03387604
# 4  2018-12-18T00:00:00.000        Open             NaN            18-03388032
#
#    Type of Service Request       Street Address  ZIP Code  X Coordinate  \
# 0  Street Lights - All/Out       119 W 112TH ST   60628.0  1.177394e+06
# 1  Street Lights - All/Out     12700 S LOWE AVE   60628.0  1.174295e+06
# 2  Street Lights - All/Out  5300 W MONTROSE AVE   60641.0  1.140226e+06
# 3  Street Lights - All/Out  5100 W MONTROSE AVE   60641.0  1.141688e+06
# 4  Street Lights - All/Out      7006 W GRACE ST   60634.0  1.128996e+06
#
# ...

# %%
lights_one_file = "311-service-requests-street-lights-one-out.csv"
lights_one_df = pd.read_csv(lights_one_file)
lights_one_df.head()
# Out:
#              Creation Date           Status          Completion Date  \
# 0  2018-12-19T00:00:00.000             Open                      NaN
# 1  2018-12-18T00:00:00.000             Open                      NaN
# 2  2018-12-18T00:00:00.000       Open - Dup                      NaN
# 3  2018-12-18T00:00:00.000             Open                      NaN
# 4  2018-12-18T00:00:00.000  Completed - Dup  2019-02-09T00:00:00.000
#
#   Service Request Number Type of Service Request      Street Address  \
# 0            18-03389670        Street Light Out      1935 W 22ND PL
# 1            18-03387095        Street Light Out    3100 N NAGLE AVE
# 2            18-03387523        Street Light Out  4399 N CENTRAL AVE
# 3            18-03387762        Street Light Out  2210 S STEWART AVE
# 4            18-03388320        Street Light Out     1016 E 101ST ST
#
#    ZIP Code  X Coordinate  Y Coordinate  Ward  Police District  \
# 0   60608.0  1.163819e+06  1.889090e+06  25.0             10.0
# ...

# %%
alley_lights_file = "311-service-requests-alley-lights-out.csv"
alley_lights_df = pd.read_csv(alley_lights_file)
alley_lights_df.head()
# Out:
#              Creation Date      Status Completion Date Service Request Number  \
# 0  2018-12-18T00:00:00.000  Open - Dup             NaN            18-03387543
# 1  2018-12-18T00:00:00.000        Open             NaN            18-03387434
# 2  2018-12-18T00:00:00.000        Open             NaN            18-03387561
# 3  2018-12-18T00:00:00.000        Open             NaN            18-03387171
# 4  2018-12-18T00:00:00.000  Open - Dup             NaN            18-03387750
#
#   Type of Service Request            Street Address  ZIP Code  X Coordinate  \
# 0         Alley Light Out         9148 S PAXTON AVE   60617.0  1.192433e+06
# 1         Alley Light Out          4430 W FULTON ST   60624.0  1.146803e+06
# 2         Alley Light Out  11311 S CENTRAL PARK AVE   60655.0  1.154392e+06
# 3         Alley Light Out         3525 N ORANGE AVE   60634.0  1.122791e+06
# 4         Alley Light Out         7244 S RHODES AVE   60619.0  1.181160e+06
#
# ...

# %%
graffiti_cols = ["Creation Date", "Service Request Number", "Type of Service Request", "ZIP Code", "Ward", "Police District", "Community Area", "What Type of Surface is the Graffiti on?" ]
graffiti_transformed= graffiti_df[graffiti_cols].copy()

# Rename the column headers
graffiti_transformed = graffiti_transformed.rename(columns={"Creation Date": "creation_date",
                                                          "Service Request Number": "service_request_number",
                                                          "Type of Service Request": "graffiti_request",
                                                          "ZIP Code": "ZIP",
                                                          "Ward": "ward",
                                                          "Police District": "police_district",
                                                          "Community Area": "community_area",
                                                          "What Type of Surface is the Graffiti on?": "graffiti_location"})

# Clean the data by dropping duplicates and setting the index
graffiti_transformed.drop_duplicates("service_request_number", inplace=True)
graffiti_transformed.set_index("service_request_number", inplace=True)

graffiti_transformed.head()
# Out:
#                                   creation_date  graffiti_request      ZIP  \
# service_request_number
# 18-03388261             2018-12-18T00:00:00.000  Graffiti Removal  60640.0
# 18-03387473             2018-12-18T00:00:00.000  Graffiti Removal  60644.0
# 18-03388465             2018-12-18T00:00:00.000  Graffiti Removal  60608.0
# 18-03388768             2018-12-18T00:00:00.000  Graffiti Removal  60608.0
# 18-03387763             2018-12-18T00:00:00.000  Graffiti Removal  60614.0
#
#                         ward  police_district  community_area  \
# service_request_number
# 18-03388261             46.0             19.0             3.0
# 18-03387473             28.0             11.0            25.0
# 18-03388465             25.0             10.0            31.0
# 18-03388768             12.0             10.0            30.0
# 18-03387763             43.0             19.0             7.0
#
#                         graffiti_location
# service_request_number
# ...

# %%
lights_all_cols = ["Creation Date", "Service Request Number", "Type of Service Request", "ZIP Code", "Ward", "Police District", "Community Area"]
lights_all_transformed= lights_all_df[lights_all_cols].copy()

# Rename the column headers
lights_all_transformed = lights_all_transformed.rename(columns={"Creation Date": "creation_date",
                                                          "Service Request Number": "service_request_number",
                                                          "Type of Service Request": "st_lights_all_request",
                                                          "ZIP Code": "ZIP",
                                                          "Ward": "ward",
                                                          "Police District": "police_district",
                                                          "Community Area": "community_area"})

# Clean the data by dropping duplicates and setting the index
lights_all_transformed.drop_duplicates("service_request_number", inplace=True)
lights_all_transformed.set_index("service_request_number", inplace=True)

lights_all_transformed.head()
# Out:
#                                   creation_date    st_lights_all_request  \
# service_request_number
# 18-03388534             2018-12-18T00:00:00.000  Street Lights - All/Out
# 18-03387781             2018-12-18T00:00:00.000  Street Lights - All/Out
# 18-03387616             2018-12-18T00:00:00.000  Street Lights - All/Out
# 18-03387604             2018-12-18T00:00:00.000  Street Lights - All/Out
# 18-03388032             2018-12-18T00:00:00.000  Street Lights - All/Out
#
#                             ZIP  ward  police_district  community_area
# service_request_number
# 18-03388534             60628.0  34.0              5.0            49.0
# 18-03387781             60628.0   9.0              5.0            53.0
# 18-03387616             60641.0  38.0             16.0            15.0
# 18-03387604             60641.0  45.0             16.0            15.0
# 18-03388032             60634.0  38.0             16.0            17.0

# %%
lights_one_cols = ["Creation Date", "Service Request Number", "Type of Service Request", "ZIP Code", "Ward", "Police District", "Community Area"]
lights_one_transformed= lights_one_df[lights_all_cols].copy()

# Rename the column headers
lights_one_transformed = lights_one_transformed.rename(columns={"Creation Date": "creation_date",
                                                          "Service Request Number": "service_request_number",
                                                          "Type of Service Request": "st_lights_one_request",
                                                          "ZIP Code": "ZIP",
                                                          "Ward": "ward",
                                                          "Police District": "police_district",
                                                          "Community Area": "community_area"})

# Clean the data by dropping duplicates and setting the index
lights_one_transformed.drop_duplicates("service_request_number", inplace=True)
lights_one_transformed.set_index("service_request_number", inplace=True)

lights_one_transformed.head()
# Out:
#                                   creation_date st_lights_one_request  \
# service_request_number
# 18-03389670             2018-12-19T00:00:00.000      Street Light Out
# 18-03387095             2018-12-18T00:00:00.000      Street Light Out
# 18-03387523             2018-12-18T00:00:00.000      Street Light Out
# 18-03387762             2018-12-18T00:00:00.000      Street Light Out
# 18-03388320             2018-12-18T00:00:00.000      Street Light Out
#
#                             ZIP  ward  police_district  community_area
# service_request_number
# 18-03389670             60608.0  25.0             10.0            31.0
# 18-03387095             60634.0  36.0             25.0            19.0
# 18-03387523             60634.0  38.0             16.0            15.0
# 18-03387762             60616.0  25.0              9.0            34.0
# 18-03388320             60628.0   8.0              5.0            50.0

# %%
alley_lights_cols = ["Creation Date", "Service Request Number", "Type of Service Request", "ZIP Code", "Ward", "Police District", "Community Area"]
alley_lights_transformed= alley_lights_df[alley_lights_cols].copy()

# Rename the column headers
alley_lights_transformed = alley_lights_transformed.rename(columns={"Creation Date": "creation_date",
                                                          "Service Request Number": "service_request_number",
                                                          "Type of Service Request": "alley_lights_request",
                                                          "ZIP Code": "ZIP",
                                                          "Ward": "ward",
                                                          "Police District": "police_district",
                                                          "Community Area": "community_area"})

# Clean the data by dropping duplicates and setting the index
alley_lights_transformed.drop_duplicates("service_request_number", inplace=True)
alley_lights_transformed.set_index("service_request_number", inplace=True)

lights_one_transformed.head()
# Out:
#                                   creation_date st_lights_one_request  \
# service_request_number
# 18-03389670             2018-12-19T00:00:00.000      Street Light Out
# 18-03387095             2018-12-18T00:00:00.000      Street Light Out
# 18-03387523             2018-12-18T00:00:00.000      Street Light Out
# 18-03387762             2018-12-18T00:00:00.000      Street Light Out
# 18-03388320             2018-12-18T00:00:00.000      Street Light Out
#
#                             ZIP  ward  police_district  community_area
# service_request_number
# 18-03389670             60608.0  25.0             10.0            31.0
# 18-03387095             60634.0  36.0             25.0            19.0
# 18-03387523             60634.0  38.0             16.0            15.0
# 18-03387762             60616.0  25.0              9.0            34.0
# 18-03388320             60628.0   8.0              5.0            50.0

# %%
database_path ="root:Rizzo-44@localhost/x311calls_db"
engine = create_engine(f"mysql://{database_path}")

# %%
engine.table_names()
# Out:
# ['alley_lights', 'graffiti', 'street_lights_all', 'street_lights_one']

# %%
# !pip install mysqlclient

# %%
graffiti_transformed.to_sql(name='graffiti', con=engine, if_exists='append', index=True)

# %%
lights_all_transformed.to_sql(name='street_lights_all', con=engine, if_exists='append', index=True)

# %%
lights_one_transformed.to_sql(name='street_lights_one', con=engine, if_exists='append', index=True)

# %%
alley_lights_transformed.to_sql(name='alley_lights', con=engine, if_exists='append', index=True)
